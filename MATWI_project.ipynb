# %%
import pandas as pd
import os

# Load one sensor CSV to inspect
df = pd.read_csv('MATWI\MATWI\Set1\sensordata\File_name_2022-09-09T13_30_37.534347.csv')

print(df.shape)        # How many rows (timesteps) and columns (channels)
print(df.head())       # First few rows
print(df.columns)      # Column names - identify which are acc, AE, force x, force y
print(df.dtypes)       # Data types
# Out:
# (88999, 6)
#    -0.001  1.156  -0.654  -0.172  0.141  2022-09-09 13:30:42.492650000
# 0   0.013  2.537  -0.655  -0.174  0.154  2022-09-09 13:30:42.493261405
# 1   0.014  2.473  -0.651  -0.170  0.148  2022-09-09 13:30:42.493872810
# 2   0.004  0.958  -0.651  -0.169  0.142  2022-09-09 13:30:42.494484215
# 3  -0.007 -0.385  -0.651  -0.171  0.147  2022-09-09 13:30:42.495095620
# 4   0.003  0.152  -0.649  -0.170  0.156  2022-09-09 13:30:42.495707025
# Index(['-0.001', '1.156', '-0.654', '-0.172', '0.141',
#        '2022-09-09 13:30:42.492650000'],
#       dtype='str')
# -0.001                           float64
# 1.156                            float64
# -0.654                           float64
# -0.172                           float64
# 0.141                            float64
# 2022-09-09 13:30:42.492650000        str
# dtype: object
