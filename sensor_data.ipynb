# %%
import pandas as pd
import numpy as np
import os

# Sensor channels from the paper
SENSOR_CHANNELS = ['acc', 'acoustic_emission', 'force_x', 'force_y', 'force_z']
N_SENSOR_CHANNELS = len(SENSOR_CHANNELS)  # 5
SAMPLE_RATE = 1626  # Hz from the paper

def load_sensor_csv(csv_path):
    """
    Load one sensor CSV for a single milling pass.

    Returns:
        np.array of shape (N_timesteps, 5)
    """
    df = pd.read_csv(csv_path, header=None)

    # Select only the 5 sensor channels (fixed: was 0:4, missing force_z)
    data = df.iloc[:, 0:N_SENSOR_CHANNELS].values.astype(np.float32)

    print(f"Loaded: {data.shape}")  # e.g., (94000, 5)
    return data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import joblib

def fit_pca_on_training_data(train_csv_paths, n_components=None, 
                              variance_threshold=0.95):
    """
    Fits PCA on all training sensor data combined.
    
    IMPORTANT: PCA must be fit ONLY on training data to avoid leakage.
    
    Args:
        train_csv_paths: list of CSV paths from training sets only
        n_components: fixed number of components (None = use variance threshold)
        variance_threshold: keep enough components to explain this much variance
    
    Returns:
        fitted scaler, fitted PCA, chosen n_components
    """
    print("Loading all training sensor data for PCA fitting...")
    
    all_data = []
    for csv_path in train_csv_paths:
        data = load_sensor_csv(csv_path)  # (N_timesteps, 5)
        all_data.append(data)
    
    # Stack all training data: (total_timesteps, 5)
    all_data = np.vstack(all_data)
    print(f"Total training timesteps for PCA: {all_data.shape}")
    
    # Step 1: StandardScaler - CRITICAL before PCA
    # PCA is sensitive to scale - sensors have very different units
    # acc is in g, force in Newtons, AE in volts - must normalize first
    scaler = StandardScaler()
    all_data_scaled = scaler.fit_transform(all_data)
    
    # Step 2: Fit PCA
    if n_components is None:
        # First fit with all components to find optimal number
        pca_full = PCA(n_components=None)
        pca_full.fit(all_data_scaled)
        
        # Find number of components to explain variance_threshold
        cumulative_variance = np.cumsum(pca_full.explained_variance_ratio_)
        n_components = np.argmax(cumulative_variance >= variance_threshold) + 1
        
        print(f"\nVariance explained by each component:")
        for i, (var, cum_var) in enumerate(
            zip(pca_full.explained_variance_ratio_, cumulative_variance)
        ):
            print(f"  PC{i+1}: {var:.4f} ({cum_var:.4f} cumulative)")
            if cum_var >= variance_threshold:
                print(f"  → {n_components} components explain "
                      f"{cum_var:.2%} of variance")
                break
        
        # Plot explained variance
        plot_pca_variance(pca_full.explained_variance_ratio_)
    
    # Step 3: Fit final PCA with chosen n_components
    pca = PCA(n_components=n_components)
    pca.fit(all_data_scaled)
    
    print(f"\nFinal PCA: {n_components} components")
    print(f"Total variance explained: "
          f"{pca.explained_variance_ratio_.sum():.4f}")
    
    # Save scaler and PCA for later use on val/test data
    joblib.dump(scaler, 'scaler.pkl')
    joblib.dump(pca,    'pca.pkl')
    
    return scaler, pca, n_components


def plot_pca_variance(explained_variance_ratio):
    """Visualize how many components are needed"""
    cumulative = np.cumsum(explained_variance_ratio)
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    # Individual variance per component
    axes[0].bar(range(1, len(explained_variance_ratio) + 1), 
                explained_variance_ratio)
    axes[0].set_xlabel('Principal Component')
    axes[0].set_ylabel('Explained Variance Ratio')
    axes[0].set_title('Variance per Component')
    
    # Cumulative variance
    axes[1].plot(range(1, len(cumulative) + 1), cumulative, 'bo-')
    axes[1].axhline(y=0.95, color='r', linestyle='--', label='95% threshold')
    axes[1].axhline(y=0.99, color='g', linestyle='--', label='99% threshold')
    axes[1].set_xlabel('Number of Components')
    axes[1].set_ylabel('Cumulative Explained Variance')
    axes[1].set_title('Cumulative Variance Explained')
    axes[1].legend()
    
    plt.tight_layout()
    plt.savefig('pca_variance.png')
    plt.show()


def apply_pca_to_pass(csv_path, scaler, pca):
    """
    Apply fitted scaler + PCA to a single milling pass.
    
    Returns:
        np.array of shape (N_timesteps, n_components)
    """
    data = load_sensor_csv(csv_path)         # (N_timesteps, 5)
    data_scaled = scaler.transform(data)     # (N_timesteps, 5) - scaled
    data_pca = pca.transform(data_scaled)    # (N_timesteps, n_components)
    
    return data_pca.astype(np.float32)

# %% [markdown]
# Single scalar wear label per pass (broadcast removed)

# %%
def build_pass_label(wear_value_um):
    """
    Returns a single normalised wear scalar for one milling pass.
    Wear is measured once per pass, so one label per pass is correct.

    Args:
        wear_value_um: scalar wear in micrometers (e.g., 187.0)

    Returns:
        float in [0, 1]
    """
    MAX_WEAR_UM = 450.0
    return np.float32(wear_value_um / MAX_WEAR_UM)

# %% [markdown]
# #### Window creation (one scalar label per window)

# %%
def create_windows(sensor_data_pca, wear_label_scalar,
                   window_size=500, stride=250):
    """
    Splits a long time series into overlapping windows.
    Each window gets a single scalar wear label (not per-timestep).

    Args:
        sensor_data_pca:   (N_timesteps, n_components)
        wear_label_scalar: float — the wear value for this entire pass
        window_size:       number of timesteps per window
        stride:            step between windows

    Returns:
        windows: (N_windows, window_size, n_components)
        labels:  (N_windows,)  — one scalar per window
    """
    n_timesteps = sensor_data_pca.shape[0]

    windows = []
    labels  = []

    for start in range(0, n_timesteps - window_size + 1, stride):
        end = start + window_size
        windows.append(sensor_data_pca[start:end, :])  # (window_size, n_components)
        labels.append(wear_label_scalar)               # scalar repeated per window

    windows = np.array(windows, dtype=np.float32)      # (N_windows, window_size, n_components)
    labels  = np.array(labels,  dtype=np.float32)      # (N_windows,)

    print(f"Created {len(windows)} windows from {n_timesteps} timesteps")
    print(f"Windows shape: {windows.shape}")

    return windows, labels

# %% [markdown]
# #### Dataset Class

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class WearRegressionDataset(Dataset):
    def __init__(self, index_df, scaler, pca,
                 window_size=500, stride=250):
        """
        Args:
            index_df:    DataFrame with columns: sensor_path, wear_value
            scaler:      fitted StandardScaler (training data only)
            pca:         fitted PCA (training data only)
            window_size: timesteps per LSTM input window
            stride:      step between windows
        """
        self.window_size = window_size
        self.stride      = stride

        self.all_windows = []
        self.all_labels  = []

        print("Preprocessing dataset...")
        for _, row in index_df.iterrows():

            # Apply PCA to sensor data
            sensor_pca = apply_pca_to_pass(
                row['sensor_path'], scaler, pca
            )  # (N_timesteps, n_components)

            # Single normalised label for this pass
            label = build_pass_label(row['wear_value'])  # scalar float32

            # Create windows — label broadcast inside create_windows
            windows, win_labels = create_windows(
                sensor_pca, label, window_size, stride
            )  # (N_windows, window_size, k), (N_windows,)

            self.all_windows.append(windows)
            self.all_labels.append(win_labels)

        self.all_windows = np.vstack(self.all_windows)   # (total_windows, window_size, k)
        self.all_labels  = np.concatenate(self.all_labels)  # (total_windows,)

        print(f"Total windows in dataset: {self.all_windows.shape[0]}")

    def __len__(self):
        return len(self.all_windows)

    def __getitem__(self, idx):
        window = self.all_windows[idx]  # (window_size, n_components)
        label  = self.all_labels[idx]   # scalar

        return {
            'sensor': torch.tensor(window, dtype=torch.float32),
            'wear':   torch.tensor(label,  dtype=torch.float32)  # scalar
        }

# %% [markdown]
# #### Declaring LSTM Model

# %%
import torch
import torch.nn as nn

class WearLSTM(nn.Module):
    def __init__(self, input_size, hidden_size=128,
                 num_layers=2, dropout=0.3):
        """
        LSTM for single wear value regression per window.
        Uses the last hidden state (not per-timestep output).

        Args:
            input_size:  number of PCA components (k)
            hidden_size: LSTM hidden state dimension
            num_layers:  number of stacked LSTM layers
            dropout:     dropout between LSTM layers
        """
        super().__init__()

        self.hidden_size = hidden_size
        self.num_layers  = num_layers

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0,
            bidirectional=True
        )

        # Bidirectional doubles hidden_size
        self.regressor = nn.Sequential(
            nn.Linear(hidden_size * 2, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, 1),
            nn.Sigmoid()   # Output in [0, 1] to match normalised wear
        )

    def forward(self, x):
        """
        Args:
            x: (batch, window_size, n_components)

        Returns:
            wear: (batch,) — single predicted wear value per window
        """
        lstm_out, _ = self.lstm(x)  # (batch, window_size, hidden_size * 2)

        # Use last timestep's output to summarise the window
        last_out = lstm_out[:, -1, :]  # (batch, hidden_size * 2)

        wear = self.regressor(last_out)  # (batch, 1)
        return wear.squeeze(-1)          # (batch,)

# %% [markdown]
# #### Training Loop

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.optim as optim
from tqdm import tqdm

def train_wear_lstm(train_loader, val_loader, n_components,
                    num_epochs=20, device='cuda'):

    model = WearLSTM(
        input_size=n_components,
        hidden_size=128,
        num_layers=2,
        dropout=0.3
    ).to(device)

    criterion = nn.MSELoss()

    optimizer = optim.AdamW(
        model.parameters(),
        lr=1e-3,
        weight_decay=1e-4
    )

    scheduler = ReduceLROnPlateau(
        optimizer, mode='min',
        factor=0.5, patience=5
    )

    best_val_loss = float('inf')
    train_losses, val_losses = [], []

    epoch_bar = tqdm(range(num_epochs), desc='Epochs', unit='epoch')


    for epoch in epoch_bar:

        # -------- Training --------
        model.train()
        epoch_train_loss = 0.0

        train_bar = tqdm(train_loader, desc=f'  Train', leave=False, unit='batch')
        for batch in train_bar:
            sensor = batch['sensor'].to(device)  # (batch, window_size, k)
            wear   = batch['wear'].to(device)    # (batch,) — scalar per window

            optimizer.zero_grad()
            predictions = model(sensor)          # (batch,)
            loss = criterion(predictions, wear)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_train_loss += loss.item()
            train_bar.set_postfix(loss=f'{loss.item():.6f}')

        avg_train_loss = epoch_train_loss / len(train_loader)

        # -------- Validation --------
        model.eval()
        epoch_val_loss = 0.0
        all_preds, all_targets = [], []

        val_bar = tqdm(val_loader, desc=f'  Val  ', leave=False, unit='batch')
        with torch.no_grad():
            for batch in val_bar:
                sensor = batch['sensor'].to(device)
                wear   = batch['wear'].to(device)

                predictions = model(sensor)      # (batch,)
                loss = criterion(predictions, wear)

                epoch_val_loss += loss.item()
                all_preds.extend(predictions.cpu().numpy().tolist())
                all_targets.extend(wear.cpu().numpy().tolist())
                val_bar.set_postfix(loss=f'{loss.item():.6f}')

        avg_val_loss = epoch_val_loss / len(val_loader)
        scheduler.step(avg_val_loss)

        # MAE in original µm scale
        all_preds   = np.array(all_preds)   * 450.0
        all_targets = np.array(all_targets) * 450.0
        mae_um = np.mean(np.abs(all_preds - all_targets))

        train_losses.append(avg_train_loss)
        val_losses.append(avg_val_loss)

        # Update epoch bar with summary stats
        current_lr = optimizer.param_groups[0]['lr']
        epoch_bar.set_postfix(
            train=f'{avg_train_loss:.6f}',
            val=f'{avg_val_loss:.6f}',
            mae=f'{mae_um:.2f}µm',
            lr=f'{current_lr:.2e}'
        )

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save({
                'epoch':       epoch,
                'model_state': model.state_dict(),
                'val_mae_um':  mae_um
            }, 'best_wear_lstm.pth')
            tqdm.write(f'  ✓ Epoch {epoch+1}: saved best model (MAE: {mae_um:.2f}µm)')

    return model, train_losses, val_losses

# %% [markdown]
# #### Entire pipeline put together

# %%
import glob
import pandas as pd
from pathlib import Path

# ---- 1. Load labels.csv ----
labels_df = pd.read_csv('MATWI/MATWI/labels.csv')

print(f"labels.csv shape: {labels_df.shape}")
print(f"Columns: {labels_df.columns.tolist()}")
print(f"NaN count in SensorFile: {labels_df['SensorFile'].isna().sum()}")
print(f"NaN count in wear:       {labels_df['wear'].isna().sum()}")

# Drop rows where SensorFile or wear is missing
labels_df = labels_df.dropna(subset=['SensorFile', 'wear'])
print(f"After dropping NaNs: {len(labels_df)} rows remain")

# Build lookup: sensor CSV filename → wear value (µm)
wear_map = {
    Path(str(row['SensorFile'])).name: float(row['wear'])
    for _, row in labels_df.iterrows()
}

print(f"\nLoaded {len(wear_map)} wear labels")
print(f"Sample entries: {list(wear_map.items())[:3]}")


# ---- 2. Collect CSV paths per set ----
all_sets = {}
for i in range(1, 18):
    all_sets[f'Set{i}'] = sorted(glob.glob(f'MATWI/MATWI/Set{i}/sensordata/*.csv'))

TRAIN_SETS = ['Set1','Set2','Set5','Set7','Set8','Set10','Set11']
VAL_SETS   = ['Set3','Set6','Set12']
TEST_SETS  = ['Set4','Set9','Set13']


# ---- 3. Build index DataFrames ----
def build_index_df(set_names):
    """
    Match every sensor CSV to its wear label from labels.csv.
    Returns a DataFrame with columns: sensor_path, wear_value, set.
    """
    rows = []
    for set_name in set_names:
        for csv_path in all_sets[set_name]:
            fname = Path(csv_path).name
            if fname in wear_map:
                rows.append({
                    'sensor_path': csv_path,
                    'wear_value':  wear_map[fname],
                    'set':         set_name
                })
            else:
                print(f"WARNING: no wear label for {fname} — skipping.")
    return pd.DataFrame(rows)


train_df = build_index_df(TRAIN_SETS)
val_df   = build_index_df(VAL_SETS)
test_df  = build_index_df(TEST_SETS)

print(f"\nTrain: {len(train_df)} passes")
print(f"Val:   {len(val_df)} passes")
print(f"Test:  {len(test_df)} passes")
print(f"\nWear range in train: {train_df['wear_value'].min():.1f} – {train_df['wear_value'].max():.1f} µm")
print(train_df.head())


# ---- 4. Fit PCA on training sensor data only ----
train_csv_paths = train_df['sensor_path'].tolist()

scaler, pca, n_components = fit_pca_on_training_data(
    train_csv_paths,
    variance_threshold=0.95
)
# Out:
# labels.csv shape: (1803, 11)
# Columns: ['ImageName', 'SensorName', 'Set', 'ImageID', 'SensorID', 'wear', 'type', 'ImageDateTime', 'SensorDateTime', 'ImageFile', 'SensorFile']
# NaN count in SensorFile: 103
# NaN count in wear:       140
# After dropping NaNs: 1566 rows remain
#
# Loaded 1566 wear labels
# Sample entries: [('File_name_2022-09-09T13_30_37.534347.csv', 30.0), ('File_name_2022-09-09T13_42_22.323924.csv', 30.0), ('File_name_2022-09-09T13_57_28.734803.csv', 60.0)]
# WARNING: no wear label for File_name_2022-09-12T09_03_06.318865.csv — skipping.
# WARNING: no wear label for File_name_2022-09-12T09_52_10.148491.csv — skipping.
# WARNING: no wear label for File_name_2022-09-12T10_31_02.305663.csv — skipping.
# WARNING: no wear label for File_name_2022-09-12T12_00_27.484393.csv — skipping.
# WARNING: no wear label for File_name_2022-09-12T12_58_13.177880.csv — skipping.
# WARNING: no wear label for File_name_2022-09-12T13_00_27.148516.csv — skipping.
# WARNING: no wear label for Test_0015_1_00_000_2022-11-17T11_00_17.104150.csv — skipping.
# WARNING: no wear label for Test_0015_1_00_001_2022-11-17T15_47_52.379226.csv — skipping.
# WARNING: no wear label for Test_0015_1_01_000_2022-11-17T15_49_43.074099.csv — skipping.
# WARNING: no wear label for Test_0015_1_01_001_2022-11-17T15_56_00.281494.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_000_2022-11-17T15_57_40.866378.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_001_2022-11-18T08_44_34.067811.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_002_2022-11-18T08_48_01.610235.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_003_2022-11-18T08_51_25.534403.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_004_2022-11-18T12_07_46.435035.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_005_2022-11-18T12_10_27.965954.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_006_2022-11-18T12_14_07.246953.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_007_2022-11-18T12_15_56.228615.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_008_2022-11-18T12_17_53.281068.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_009_2022-11-23T09_25_23.449771.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_000_2022-11-23T09_27_01.178992.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_005_2022-11-24T09_57_18.228154.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_032_2022-11-24T11_19_52.008325.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_062_2022-11-24T14_01_37.449966.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_310_2023-02-21T10_29_00.449717.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_320_2023-02-21T10_49_53.492858.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_330_2023-02-21T11_08_25.798403.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_340_2023-02-21T11_30_10.583574.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_348_2023-02-21T11_56_08.736157.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_358_2023-02-21T12_39_50.765726.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_368_2023-02-21T13_02_10.878738.csv — skipping.
# WARNING: no wear label for Test_0015_1_00_000_2023-02-23T09_05_04.092229.csv — skipping.
# WARNING: no wear label for Test_0015_1_00_051_2023-02-23T10_43_30.823994.csv — skipping.
# WARNING: no wear label for Test_0015_1_00_017_2023-02-24T09_13_50.235681.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_050_2023-02-24T10_08_21.403074.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_102_2023-03-02T11_47_44.109607.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_153_2023-03-02T13_35_28.296301.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_204_2023-03-06T09_15_57.363946.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_255_2023-03-06T10_49_38.962753.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_100_2022-12-20T09_46_14.527579.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_157_2022-12-23T11_14_41.492801.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_378_2023-02-22T08_35_43.560619.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_379_2023-02-22T08_37_22.506449.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_380_2023-02-22T08_39_04.733495.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_381_2023-02-22T08_40_45.124697.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_382_2023-02-22T08_42_27.436045.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_383_2023-02-22T08_44_07.974727.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_384_2023-02-22T08_45_50.251482.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_385_2023-02-22T08_47_32.218137.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_386_2023-02-22T08_49_13.047952.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_387_2023-02-22T08_50_54.843066.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_388_2023-02-22T09_04_03.943878.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_398_2023-02-22T09_25_38.555454.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_408_2023-02-22T09_48_51.061329.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_418_2023-02-22T10_17_36.286603.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_428_2023-02-22T10_41_05.981092.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_438_2023-02-22T11_21_33.814199.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_439_2023-02-22T11_23_04.811235.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_440_2023-02-22T11_24_35.566161.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_441_2023-02-22T11_26_05.079755.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_442_2023-02-22T11_27_36.095452.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_443_2023-02-22T11_29_07.199126.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_444_2023-02-22T11_30_38.029094.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_445_2023-02-22T11_32_07.371731.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_446_2023-02-22T11_33_38.439233.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_447_2023-02-22T11_35_09.306321.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_448_2023-02-22T11_36_40.044250.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_449_2023-02-22T11_38_09.514105.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_450_2023-02-22T11_39_40.477128.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_451_2023-02-22T11_41_11.466734.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_452_2023-02-22T11_42_42.569040.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_453_2023-02-22T11_44_11.864603.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_454_2023-02-22T11_45_42.865550.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_455_2023-02-22T11_47_13.732108.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_456_2023-02-22T11_48_44.631101.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_457_2023-02-22T11_50_14.022951.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_458_2023-02-22T11_51_45.116549.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_459_2023-02-22T11_53_16.190615.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_460_2023-02-22T11_54_47.316341.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_461_2023-02-22T11_56_18.241404.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_462_2023-02-22T11_57_49.188639.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_463_2023-02-22T11_59_18.703670.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_464_2023-02-22T12_00_49.695176.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_465_2023-02-22T12_02_20.661507.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_466_2023-02-22T12_03_51.749561.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_467_2023-02-22T12_05_21.277442.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_468_2023-02-22T12_06_52.320565.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_469_2023-02-22T12_08_23.500070.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_470_2023-02-22T12_09_54.780683.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_471_2023-02-22T12_11_25.599720.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_472_2023-02-22T12_12_56.257815.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_473_2023-02-22T12_14_27.198649.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_474_2023-02-22T12_15_56.675348.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_475_2023-02-22T12_17_27.662720.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_476_2023-02-22T12_18_58.791817.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_477_2023-02-22T12_20_29.934564.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_478_2023-02-22T12_22_00.956922.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_479_2023-02-22T12_23_31.882942.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_480_2023-02-22T12_25_02.912139.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_481_2023-02-22T12_26_33.788430.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_482_2023-02-22T12_28_04.754001.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_483_2023-02-22T12_29_35.711173.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_484_2023-02-22T12_31_06.622769.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_485_2023-02-22T12_32_37.580310.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_486_2023-02-22T12_34_08.384497.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_487_2023-02-22T12_35_39.786899.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_488_2023-02-22T12_37_10.192683.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_000_2023-03-13T09_27_16.909394.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_001_2023-03-13T09_37_18.546592.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_002_2023-03-13T09_41_33.658042.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_205_2023-02-16T10_48_57.035551.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_227_2023-02-17T09_06_16.081963.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_252_2023-02-20T09_16_41.417091.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_259_2023-02-20T10_30_22.442890.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_280_2023-02-20T11_46_20.139070.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_296_2023-02-21T09_34_55.139428.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_298_2023-02-21T09_42_04.599650.csv — skipping.
# WARNING: no wear label for Test_0015_1_03_300_2023-02-21T09_58_39.030525.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_000_2023-03-02T08_52_03.459235.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_036_2023-03-02T09_47_57.581291.csv — skipping.
# WARNING: no wear label for Test_0015_1_02_053_2023-03-16T09_22_36.078388.csv — skipping.
#
# Train: 647 passes
# Val:   300 passes
# Test:  247 passes
#
# Wear range in train: 15.0 – 750.0 µm
#                                          sensor_path  wear_value   set
# 0  MATWI/MATWI/Set1/sensordata\File_name_2022-09-...        30.0  Set1
# 1  MATWI/MATWI/Set1/sensordata\File_name_2022-09-...        30.0  Set1
# 2  MATWI/MATWI/Set1/sensordata\File_name_2022-09-...        60.0  Set1
# 3  MATWI/MATWI/Set1/sensordata\File_name_2022-09-...        90.0  Set1
# 4  MATWI/MATWI/Set1/sensordata\File_name_2022-09-...        30.0  Set1
# Loading all training sensor data for PCA fitting...
# Loaded: (89000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (75000, 5)
# Loaded: (75000, 5)
# Loaded: (78000, 5)
# Loaded: (76000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (75000, 5)
# Loaded: (73000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (75000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (80000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (73000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (80000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (80000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (76000, 5)
# Loaded: (80000, 5)
# Loaded: (75000, 5)
# Loaded: (81000, 5)
# Loaded: (80000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (108000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (75000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (76000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (76000, 5)
# Loaded: (78000, 5)
# Loaded: (75000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (76000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (75000, 5)
# Loaded: (80000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (80000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (78000, 5)
# Loaded: (81000, 5)
# Loaded: (81000, 5)
# Loaded: (76000, 5)
# Loaded: (81000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# Loaded: (100000, 5)
# Loaded: (100000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# Loaded: (100000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# Loaded: (99000, 5)
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[8], line 72
#      69 # ---- 4. Fit PCA on training sensor data only ----
#      70 train_csv_paths = train_df['sensor_path'].tolist()
# ---> 72 scaler, pca, n_components = fit_pca_on_training_data(
#      73     train_csv_paths,
#      74     variance_threshold=0.95
#      75 )
#
# Cell In[2], line 25, in fit_pca_on_training_data(train_csv_paths, n_components, variance_threshold)
#      23 all_data = []
#      24 for csv_path in train_csv_paths:
# ---> 25     data = load_sensor_csv(csv_path)  # (N_timesteps, 5)
#      26     all_data.append(data)
#      28 # Stack all training data: (total_timesteps, 5)
#
# Cell In[1], line 17, in load_sensor_csv(csv_path)
#      10 def load_sensor_csv(csv_path):
#      11     """
#      12     Load one sensor CSV for a single milling pass.
#      13
#      14     Returns:
#      15         np.array of shape (N_timesteps, 5)
#      16     """
# ---> 17     df = pd.read_csv(csv_path, header=None)
#      19     # Select only the 5 sensor channels (fixed: was 0:4, missing force_z)
#      20     data = df.iloc[:, 0:N_SENSOR_CHANNELS].values.astype(np.float32)
#
# File e:\DF\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File e:\DF\.venv\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File e:\DF\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File e:\DF\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper.read(self, nrows)
#     213 try:
#     214     if self.low_memory:
# --> 215         chunks = self._reader.read_low_memory(nrows)
#     216         # destructive to chunks
#     217         data = _concatenate_chunks(chunks, self.names)
#
# File pandas/_libs/parsers.pyx:832, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:897, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2084, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# Apply scalar+PCA to val and test datasets

train_dataset = WearRegressionDataset(
    train_df, scaler, pca, window_size=500, stride=250
)
val_dataset = WearRegressionDataset(
    val_df, scaler, pca, window_size=500, stride=500  # No overlap for eval
)
test_dataset = WearRegressionDataset(
    test_df, scaler, pca, window_size=500, stride=500
)


# ---- 5. Create DataLoaders ----
train_loader = DataLoader(
    train_dataset, batch_size=32, shuffle=True,  num_workers=0
)
val_loader = DataLoader(
    val_dataset,   batch_size=32, shuffle=False, num_workers=0
)
test_loader = DataLoader(
    test_dataset,  batch_size=32, shuffle=False, num_workers=0
)

# ---- 6. Train ----
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model, train_losses, val_losses = train_wear_lstm(
    train_loader, val_loader,
    n_components=n_components,
    num_epochs=20,
    device=device
)
# Out:
# Preprocessing dataset...
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (76000, 5)
# Created 303 windows from 76000 timesteps
# Windows shape: (303, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (73000, 5)
# Created 291 windows from 73000 timesteps
# Windows shape: (291, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (73000, 5)
# Created 291 windows from 73000 timesteps
# Windows shape: (291, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (76000, 5)
# Created 303 windows from 76000 timesteps
# Windows shape: (303, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (108000, 5)
# Created 431 windows from 108000 timesteps
# Windows shape: (431, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (76000, 5)
# Created 303 windows from 76000 timesteps
# Windows shape: (303, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (76000, 5)
# Created 303 windows from 76000 timesteps
# Windows shape: (303, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (76000, 5)
# Created 303 windows from 76000 timesteps
# Windows shape: (303, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (75000, 5)
# Created 299 windows from 75000 timesteps
# Windows shape: (299, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (78000, 5)
# Created 311 windows from 78000 timesteps
# Windows shape: (311, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (76000, 5)
# Created 303 windows from 76000 timesteps
# Windows shape: (303, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (101000, 5)
# Created 403 windows from 101000 timesteps
# Windows shape: (403, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (101000, 5)
# Created 403 windows from 101000 timesteps
# Windows shape: (403, 500, 4)
# Loaded: (101000, 5)
# Created 403 windows from 101000 timesteps
# Windows shape: (403, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (97000, 5)
# Created 387 windows from 97000 timesteps
# Windows shape: (387, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (96000, 5)
# Created 383 windows from 96000 timesteps
# Windows shape: (383, 500, 4)
# Loaded: (98000, 5)
# Created 391 windows from 98000 timesteps
# Windows shape: (391, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (97000, 5)
# Created 387 windows from 97000 timesteps
# Windows shape: (387, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (97000, 5)
# Created 387 windows from 97000 timesteps
# Windows shape: (387, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (98000, 5)
# Created 391 windows from 98000 timesteps
# Windows shape: (391, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (98000, 5)
# Created 391 windows from 98000 timesteps
# Windows shape: (391, 500, 4)
# Loaded: (98000, 5)
# Created 391 windows from 98000 timesteps
# Windows shape: (391, 500, 4)
# Loaded: (97000, 5)
# Created 387 windows from 97000 timesteps
# Windows shape: (387, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (100000, 5)
# Created 399 windows from 100000 timesteps
# Windows shape: (399, 500, 4)
# Loaded: (98000, 5)
# Created 391 windows from 98000 timesteps
# Windows shape: (391, 500, 4)
# Loaded: (99000, 5)
# Created 395 windows from 99000 timesteps
# Windows shape: (395, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (90000, 5)
# Created 359 windows from 90000 timesteps
# Windows shape: (359, 500, 4)
# Loaded: (90000, 5)
# Created 359 windows from 90000 timesteps
# Windows shape: (359, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (89000, 5)
# Created 355 windows from 89000 timesteps
# Windows shape: (355, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (88000, 5)
# Created 351 windows from 88000 timesteps
# Windows shape: (351, 500, 4)
# Loaded: (88000, 5)
# Created 351 windows from 88000 timesteps
# Windows shape: (351, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (86000, 5)
# Created 343 windows from 86000 timesteps
# Windows shape: (343, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (87000, 5)
# Created 347 windows from 87000 timesteps
# Windows shape: (347, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (83000, 5)
# Created 331 windows from 83000 timesteps
# Windows shape: (331, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (85000, 5)
# Created 339 windows from 85000 timesteps
# Windows shape: (339, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (82000, 5)
# Created 327 windows from 82000 timesteps
# Windows shape: (327, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (80000, 5)
# Created 319 windows from 80000 timesteps
# Windows shape: (319, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (84000, 5)
# Created 335 windows from 84000 timesteps
# Windows shape: (335, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# Created 323 windows from 81000 timesteps
# Windows shape: (323, 500, 4)
# Loaded: (81000, 5)
# ...
# Windows shape: (162, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (80000, 5)
# Created 160 windows from 80000 timesteps
# Windows shape: (160, 500, 4)
# Loaded: (80000, 5)
# Created 160 windows from 80000 timesteps
# Windows shape: (160, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (82000, 5)
# Created 164 windows from 82000 timesteps
# Windows shape: (164, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (82000, 5)
# Created 164 windows from 82000 timesteps
# Windows shape: (164, 500, 4)
# Loaded: (81000, 5)
# Created 162 windows from 81000 timesteps
# Windows shape: (162, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (83000, 5)
# Created 166 windows from 83000 timesteps
# Windows shape: (166, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (85000, 5)
# Created 170 windows from 85000 timesteps
# Windows shape: (170, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (83000, 5)
# Created 166 windows from 83000 timesteps
# Windows shape: (166, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (89000, 5)
# Created 178 windows from 89000 timesteps
# Windows shape: (178, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (83000, 5)
# Created 166 windows from 83000 timesteps
# Windows shape: (166, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (83000, 5)
# Created 166 windows from 83000 timesteps
# Windows shape: (166, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (87000, 5)
# Created 174 windows from 87000 timesteps
# Windows shape: (174, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (86000, 5)
# Created 172 windows from 86000 timesteps
# Windows shape: (172, 500, 4)
# Loaded: (84000, 5)
# Created 168 windows from 84000 timesteps
# Windows shape: (168, 500, 4)
# Loaded: (85000, 5)
# Created 170 windows from 85000 timesteps
# Windows shape: (170, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (92000, 5)
# Created 184 windows from 92000 timesteps
# Windows shape: (184, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (97000, 5)
# Created 194 windows from 97000 timesteps
# Windows shape: (194, 500, 4)
# Loaded: (95000, 5)
# Created 190 windows from 95000 timesteps
# Windows shape: (190, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (97000, 5)
# Created 194 windows from 97000 timesteps
# Windows shape: (194, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (95000, 5)
# Created 190 windows from 95000 timesteps
# Windows shape: (190, 500, 4)
# Loaded: (94000, 5)
# Created 188 windows from 94000 timesteps
# Windows shape: (188, 500, 4)
# Loaded: (95000, 5)
# Created 190 windows from 95000 timesteps
# Windows shape: (190, 500, 4)
# Loaded: (95000, 5)
# Created 190 windows from 95000 timesteps
# Windows shape: (190, 500, 4)
# Total windows in dataset: 42332
# Epochs:   2%|▏         | 1/50 [06:05<4:58:10, 365.12s/epoch, lr=1.00e-03, mae=67.31µm, train=0.020629, val=0.056407]
#   ✓ Epoch 1: saved best model (MAE: 67.31µm)
# Epochs:  14%|█▍        | 7/50 [36:23<3:28:45, 291.29s/epoch, lr=1.00e-03, mae=74.57µm, train=0.007423, val=0.054186]
#   ✓ Epoch 7: saved best model (MAE: 74.57µm)
# Epochs:  38%|███▊      | 19/50 [1:31:17<2:21:55, 274.69s/epoch, lr=5.00e-04, mae=72.11µm, train=0.004831, val=0.052128]
#   ✓ Epoch 19: saved best model (MAE: 72.11µm)
# Epochs: 100%|██████████| 50/50 [3:57:19<00:00, 284.79s/epoch, lr=1.56e-05, mae=75.47µm, train=0.002934, val=0.059738]
